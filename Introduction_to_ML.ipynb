# %% [markdown]
# <a href="https://colab.research.google.com/github/fduffy33/MoodleColabExercises/blob/main/Introduction_to_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Introduction to Machine Learning with Python**
#
# Welcome to your first machine learning tutorial!
# In this worksheet, we'll introduce you to basic machine learning concepts using Python and some popular libraries. You'll learn how to:
#
# Load and explore data
# Train simple machine learning models
# Make predictions with the trained models
#
# **We'll use the following libraries:**
#
# NumPy for numerical computations
# scikit-learn for machine learning models

# %% [markdown]
# ## **## Getting Started with Google Colab**
#
# Google Colab is a cloud-based platform that allows you to run Python code in your browser. To start using Colab, go to [Google Colab](https://colab.research.google.com/) and create a new notebook.

# %% [markdown]
# **Step 1: Importing Libraries**
#
# First, we need to import the necessary libraries. Run the following code to do this:

# %% [markdown]
# ![Importing libraries.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Step 2: Linear Regression**
#
# Explanation
#
# Linear regression is used to model the relationship between a dependent variable and one or more independent variables. It predicts continuous outcomes.
#
# Code
# Let's create a simple linear regression model.

# %%
import numpy as np
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

# Sample data
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([1, 3, 2, 3, 5])

# Create and fit the model
linear_model = LinearRegression()
linear_model.fit(X, y)

# Make a prediction
linear_prediction = linear_model.predict(np.array([[6]]))
print(f'Linear Regression prediction for input 6: {linear_prediction}')
# Out:
# Linear Regression prediction for input 6: [5.2]

# %% [markdown]
# **Exercise**  *Modify the code to predict the output for input 7*.

# %% [markdown]
# ### **Step 3: Logistic Regression**
#
# Explanation
#
# Logistic regression is used for binary classification problems, predicting whether an input belongs to one of two classes.
#
# Code
#
# Let's create a simple logistic regression model.
